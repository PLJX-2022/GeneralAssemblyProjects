# %% [markdown]
# <img src="http://imgur.com/1ZcRyrc.png" style="float: left; margin: 20px; height: 55px">
#
# # <u><b>Capstone:</b></u> Recommending adjacent jobs to platfrom delivery riders using NLP and consine similarity

# %% [markdown]
# ---
# ### Part 2: Clean adjacent job - F&B Grader job postings from jobsites
# ---

# %%
# Import libraries
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from PIL import Image, ImageOps
from wordcloud import WordCloud, STOPWORDS
from matplotlib_venn import venn2
import nltk
from nltk.sentiment import SentimentIntensityAnalyzer

# user-defined functions
from eda_utils import show_missing, clean_string, get_top_post

# %%
# load scrapped job postings
posts=pd.read_csv('../Data/.csv')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[2], line 2
#       1 # load scrapped job postings
# ----> 2 posts=pd.read_csv('../Data/87515_FnBGrader.csv')
#
# File /opt/homebrew/Caskroom/miniconda/base/envs/dsi-sg/lib/python3.9/site-packages/pandas/io/parsers/readers.py:912, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#     899 kwds_defaults = _refine_defaults_read(
#     900     dialect,
#     901     delimiter,
#    (...)
#     908     dtype_backend=dtype_backend,
#     909 )
#     910 kwds.update(kwds_defaults)
# --> 912 return _read(filepath_or_buffer, kwds)
#
# File /opt/homebrew/Caskroom/miniconda/base/envs/dsi-sg/lib/python3.9/site-packages/pandas/io/parsers/readers.py:577, in _read(filepath_or_buffer, kwds)
#     574 _validate_names(kwds.get("names", None))
#     576 # Create the parser.
# --> 577 parser = TextFileReader(filepath_or_buffer, **kwds)
#     579 if chunksize or iterator:
#     580     return parser
#
# File /opt/homebrew/Caskroom/miniconda/base/envs/dsi-sg/lib/python3.9/site-packages/pandas/io/parsers/readers.py:1407, in TextFileReader.__init__(self, f, engine, **kwds)
#    1404     self.options["has_index_names"] = kwds["has_index_names"]
#    1406 self.handles: IOHandles | None = None
# -> 1407 self._engine = self._make_engine(f, self.engine)
#
# File /opt/homebrew/Caskroom/miniconda/base/envs/dsi-sg/lib/python3.9/site-packages/pandas/io/parsers/readers.py:1661, in TextFileReader._make_engine(self, f, engine)
#    1659     if "b" not in mode:
#    1660         mode += "b"
# -> 1661 self.handles = get_handle(
#    1662     f,
#    1663     mode,
#    1664     encoding=self.options.get("encoding", None),
#    1665     compression=self.options.get("compression", None),
#    1666     memory_map=self.options.get("memory_map", False),
#    1667     is_text=is_text,
#    1668     errors=self.options.get("encoding_errors", "strict"),
#    1669     storage_options=self.options.get("storage_options", None),
#    1670 )
#    1671 assert self.handles is not None
#    1672 f = self.handles.handle
#
# File /opt/homebrew/Caskroom/miniconda/base/envs/dsi-sg/lib/python3.9/site-packages/pandas/io/common.py:859, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     854 elif isinstance(handle, str):
#     855     # Check whether the filename is to be opened in binary mode.
#     856     # Binary mode does not support 'encoding' and 'newline'.
#     857     if ioargs.encoding and "b" not in ioargs.mode:
#     858         # Encoding
# --> 859         handle = open(
#     860             handle,
#     861             ioargs.mode,
#     862             encoding=ioargs.encoding,
#     863             errors=errors,
#     864             newline="",
#     865         )
#     866     else:
#     867         # Binary mode
#     868         handle = open(handle, ioargs.mode)
#
# FileNotFoundError: [Errno 2] No such file or directory: '../Data/87515_FnBGrader.csv'

# %%
posts
# Out:
#       job_exp_required                                          job_title
# 0                    3                                       CLASS DRIVER  \
# 1                    3                                       DRIVER LORRY
# 2                    2                                             DRIVER
# 3                    2                                             DRIVER
# 4                    1                                             DRIVER
# ...                ...                                                ...
# 7331                 2                                  SEATER VAN DRIVER
# 7332                 5                                             DRIVER
# 7333                 2                                  DRIVER CUM WORKER
# 7334                 1  FREELANCE PART TIME CLASS A VAN DELIVERY DRIVE...
# 7335                 5                                             DRIVER
#
#       job_ssoc                                    job_description  job_salary
# 0        83329  DRIVER AND DELIVERY WORK LOCATION 2 BUROH CRES...      4000.0
# 1        83321  RESPONSIBILITIES TRANSPORT BINS AND GOODS TO C...      3750.0
# 2        83329  FOOD MANUFACTURING COMPANY, DUE TO NATURAL OF ...      3000.0
# 3        83329  ROLES &RESPONSIBILITIES TO BE SUCCESSFUL AS A ...      4000.0
# 4        83329  RESPONSIBILITIES DRIVING BETWEEN PICK UP WAREH...      3250.0
# ...        ...                                                ...         ...
# 7331     83329  JOB DESCRIPTIONS FETCH STAFF FROM DESIGNATED P...      2250.0
# 7332     83329  DESCRIPTION OF JOB TASK AND RESPONSIBILITIES T...      1800.0
# 7333     83329  JOB SCOPES FETCH WORKER TO & BACK FROM WORK SI...      2550.0
# 7334     83329  FREELANCE PART TIME CLASS 3A VAN DELIVERY DRIV...        11.0
# 7335     83329  LOCATION WORKPLACE JURONG ISLAND JOB DESCRIPTI...      2750.0
#
# [7336 rows x 5 columns]

# %%
posts['job_salary'].quantile([0.25, 0.5, 0.75])
# Out:
# 0.25    2300.0
# 0.50    2850.0
# 0.75    3250.0
# Name: job_salary, dtype: float64

# %%
posts['job_exp_required'].quantile([0.25, 0.5, 0.75])
# Out:
# 0.25    1.0
# 0.50    2.0
# 0.75    3.0
# Name: job_exp_required, dtype: float64

# %%
posts=posts[['job_description']].copy(deep=True)
posts['job_description']=posts['job_description'].map(lambda x: x.lower().strip())

# %%
show_missing(posts)
# Out:
#           variable   dtype  count  nunique  missing  pc_missing
# 0  job_description  object   7336     7336        0         0.0

# %%
# Proprocess title_text
posts['job_desc_proc']=posts['job_description'].map(lambda x: clean_string(x, stem='spacy'))

# have explored using NLTK's stemming and lemmazitaion as well. spaCy's lemmazitation produces better results. 
# spaCy lemmatization is better than NLTK lemmatization as it takes into account part-of-speech tag by default
# lemmatization is better than stemming as context of text is important for this analysis.

# %%
posts
# Out:
#                                         job_description
# 0     driver and delivery work location 2 buroh cres...  \
# 1     responsibilities transport bins and goods to c...
# 2     food manufacturing company, due to natural of ...
# 3     roles &responsibilities to be successful as a ...
# 4     responsibilities driving between pick up wareh...
# ...                                                 ...
# 7331  job descriptions fetch staff from designated p...
# 7332  description of job task and responsibilities t...
# 7333  job scopes fetch worker to & back from work si...
# 7334  freelance part time class 3a van delivery driv...
# 7335  location workplace jurong island job descripti...
#
#                                           job_desc_proc
# 0     delivery location buroh crescent ace buroh sin...
# 1     responsibility transport bin good customer loc...
# 2     food manufacture company natural business look...
# 3     role responsibilitie successful company ensure...
# 4     responsibility drive pick warehouse destinatio...
# ...                                                 ...
# 7331  description fetch staff designate pick point w...
# 7332  task responsibility shuttle navy officer famil...
# 7333  scope fetch worker site assist purchase constr...
# 7334  freelance time class van delivery hour shift t...
# 7335  location workplace jurong island chauffeur kor...
#
# [7336 rows x 2 columns]

# %%
# Read the whole text.
text = ' '.join(posts['job_desc_proc'])
# read the mask image
van_mask = np.array(Image.open('../Pictures/truck.png'))

stopwords = set(STOPWORDS)
stopwords.update(["description","requirement","responsibility","singapore","duty","work","driver","job"])

wc = WordCloud(background_color="white", max_words=200, mask=van_mask, collocations=False,
               stopwords=stopwords, contour_width=3, contour_color='steelblue')

# generate word cloud
wc.generate(text)

# show
plt.imshow(wc, interpolation='bilinear')
plt.axis("off")
plt.figure()
plt.show()

# %%
# CountVectorizer simply counts the number of times a word appears in a document (using a bag-of-words approach), 
# while TF-IDF Vectorizer takes into account not only how many times a word appears in a document 
# but also how important that word is to the whole corpus. TF-IDF Vectorizer is used below:

# %%
fig, ax = plt.subplots(1, 3, figsize=(12,3))

g1=sns.barplot(data=get_top_post(posts['job_desc_proc'], ngram_range=(1,1), n=10),
               y='feature_names', x='tfidf_scores', ax = ax[0], palette='Greens')
g1.set_title(f'top words')

g2=sns.barplot(data=get_top_post(input=posts['job_desc_proc'], ngram_range=(2,2), n=10),
               y='feature_names', x='tfidf_scores', ax = ax[1], palette='Oranges')
g2.set_title(f'top bigrams')

g3=sns.barplot(data=get_top_post(input=posts['job_desc_proc'], ngram_range=(3,3), n=10),
               y='feature_names', x='tfidf_scores', ax = ax[2], palette='bone')
g3.set_title(f'top trigrames')

plt.suptitle('Top Words', fontsize=20)
plt.tight_layout()

# %%
posts.to_csv('../Data/7515_FnBGrader_cleaned.csv', index=False)

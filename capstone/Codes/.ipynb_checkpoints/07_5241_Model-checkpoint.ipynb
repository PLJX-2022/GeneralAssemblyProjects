# %% [markdown]
# <img src="http://imgur.com/1ZcRyrc.png" style="float: left; margin: 20px; height: 55px">
#
# # <u><b>Capstone:</b></u> Recommending adjacent jobs to platfrom delivery riders using NLP and consine similarity

# %% [markdown]
# ---
# ### Part 2-01: Compare adjacent job - Model against base job
# ---

# %% [markdown]
# Fashion models wear and display clothing and accessories and post for photogaphs, film and video, advertising, still photography or for artistic creation
#
# <p><u>1. KNOWLEDGE</u><br>
# (a). <code>Business</code>
# - customer service
# (b). <code>Arts and Humanities</code>
# - English language</p>
#
# <p><u>2. SKILLS</u><br>
# (a). <code>Basic Skills</code>
# - listening to others, not interrupting, and asking good questions
# (b). <code>Social</code>
# - understanding people's reactions</p>
#
# <p><u>3. ABILITIES</u><br>
# (a). <code>Verbal</code>
# - listen and understand what people say
# (b). <code>Flexibility, Balance, and Coordination</code>
# - keep your balance or stay upright
#
# <p><u>4. PERSONALITY</u><br>
# People interested in this work like activities that include creating, designing, and making your own rules. They do well at jobs that need: <code>Dependability</code>, <code>Integrity</code>, <code>Cooperation</code>, <code>Self Control</code>, <code>Adaptability/Flexibility</code>, <code>Independence</code>

# %%
# Import libraries
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from PIL import Image, ImageOps
from wordcloud import WordCloud
from matplotlib_venn import venn2

from sklearn.feature_extraction.text import CountVectorizer
from sklearn.metrics.pairwise import cosine_similarity 

# user-defined functions
from eda_utils import show_missing, clean_string, get_top_post

# %%
# load scrapped job postings
posts=pd.read_csv('../Data/5241_Model.csv')

# %%
posts
# Out:
#     job_exp_required                  job_title  job_ssoc
# 0                  1               MODEL TALENT     52411  \
# 1                  1               MODEL TALENT     52411
# 2                  1               MODEL TALENT     52411
# 3                  0  PART TIME YOUTUBE TALENTS     52419
# 4                  1               MODEL TALENT     52411
# 5                  0  PART TIME YOUTUBE TALENTS     52419
# 6                  1               MODEL TALENT     52411
# 7                  0  PART TIME YOUTUBE TALENTS     52419
# 8                  0  PART TIME YOUTUBE TALENTS     52419
# 9                  2                      MODEL     52411
# 10                 0  PART TIME YOUTUBE TALENTS     52419
# 11                 2                      MODEL     52411
# 12                 0  PART TIME YOUTUBE TALENTS     52419
#
#                                       job_description  job_salary
# 0   AS A PLATFORM WHICH CONNECTS MODELS AND TALENT...         850
# 1   AS A PLATFORM WHICH CONNECTS MODELS AND TALENT...         850
# 2   AS A PLATFORM WHICH CONNECTS MODELS AND TALENT...         850
# 3   COMPANY OVERVIEW WE ARE SETTING UP A NEW BUSIN...        2200
# 4   A FASHION MODEL REPRESENTS BRANDS AND DESIGNER...         550
# 5   COMPANY OVERVIEW WE ARE SETTING UP A NEW BUSIN...        2200
# 6   A FASHION MODEL REPRESENTS BRANDS AND DESIGNER...         550
# 7   COMPANY OVERVIEW WE ARE SETTING UP A NEW BUSIN...        2200
# 8   COMPANY OVERVIEW WE ARE SETTING UP A NEW BUSIN...        2200
# 9   LOOKING FOR A GOOD LOOKING TALL MODEL AGE 20 3...         750
# 10  COMPANY OVERVIEW WE ARE SETTING UP A NEW BUSIN...        2200
# 11  LOOKING FOR A GOOD LOOKING TALL MODEL AGE 20 3...         750
# 12  COMPANY OVERVIEW WE ARE SETTING UP A NEW BUSIN...        2200

# %%
posts['job_salary'].quantile([0.25, 0.5, 0.75])
# Out:
# 0.25     750.0
# 0.50     850.0
# 0.75    2200.0
# Name: job_salary, dtype: float64

# %%
posts['job_exp_required'].quantile([0.25, 0.5, 0.75])
# Out:
# 0.25    0.0
# 0.50    1.0
# 0.75    1.0
# Name: job_exp_required, dtype: float64

# %%
posts=posts[['job_description']].copy(deep=True)
posts['job_description']=posts['job_description'].map(lambda x: x.lower().strip())

# %%
show_missing(posts)
# Out:
#           variable   dtype  count  nunique  missing  pc_missing
# 0  job_description  object     13        4        0         0.0

# %%
# Proprocess title_text
posts['job_desc_proc']=posts['job_description'].map(lambda x: clean_string(x, stem='spacy'))

# have explored using NLTK's stemming and lemmazitaion as well. spaCy's lemmazitation produces better results. 
# spaCy lemmatization is better than NLTK lemmatization as it takes into account part-of-speech tag by default
# lemmatization is better than stemming as context of text is important for this analysis.

# %%
posts
# Out:
#                                       job_description
# 0   as a platform which connects models and talent...  \
# 1   as a platform which connects models and talent...
# 2   as a platform which connects models and talent...
# 3   company overview we are setting up a new busin...
# 4   a fashion model represents brands and designer...
# 5   company overview we are setting up a new busin...
# 6   a fashion model represents brands and designer...
# 7   company overview we are setting up a new busin...
# 8   company overview we are setting up a new busin...
# 9   looking for a good looking tall model age 20 3...
# 10  company overview we are setting up a new busin...
# 11  looking for a good looking tall model age 20 3...
# 12  company overview we are setting up a new busin...
#
#                                         job_desc_proc
# 0   platform connect model talent client look suit...
# 1   platform connect model talent client look suit...
# 2   platform connect model talent client look suit...
# 3   overview set new business venture medium run y...
# 4   fashion model represent brand designer wear cl...
# 5   overview set new business venture medium run y...
# 6   fashion model represent brand designer wear cl...
# 7   overview set new business venture medium run y...
# 8   overview set new business venture medium run y...
# 9   look good look tall model age menswear brand t...
# 10  overview set new business venture medium run y...
# 11  look good look tall model age menswear brand t...
# 12  overview set new business venture medium run y...

# %%
# Read the whole text.
text = ' '.join(posts['job_desc_proc'])
# read the mask image
van_mask = np.array(Image.open('../Pictures/catwalk.png'))

wc = WordCloud(background_color="white", max_words=200, mask=van_mask, collocations=False, contour_width=3, contour_color='steelblue')

# generate word cloud
wc.generate(text)

# show
plt.imshow(wc, interpolation='bilinear')
plt.axis("off")
plt.figure()
plt.show()

# %%
# CountVectorizer simply counts the number of times a word appears in a document (using a bag-of-words approach), 
# while TF-IDF Vectorizer takes into account not only how many times a word appears in a document 
# but also how important that word is to the whole corpus. TF-IDF Vectorizer is used below:

# %%
fig, ax = plt.subplots(1, 3, figsize=(12,3))

g1=sns.barplot(data=get_top_post(posts['job_desc_proc'], ngram_range=(1,1), n=10),
               y='feature_names', x='tfidf_scores', ax = ax[0], palette='Greens')
g1.set_title(f'top words')

g2=sns.barplot(data=get_top_post(input=posts['job_desc_proc'], ngram_range=(2,2), n=10),
               y='feature_names', x='tfidf_scores', ax = ax[1], palette='Oranges')
g2.set_title(f'top bigrams')

g3=sns.barplot(data=get_top_post(input=posts['job_desc_proc'], ngram_range=(3,3), n=10),
               y='feature_names', x='tfidf_scores', ax = ax[2], palette='bone')
g3.set_title(f'top trigrames')

plt.suptitle('Top Words', fontsize=20)
plt.tight_layout()

# %%
posts.to_csv('../Data/5241_Model_cleaned.csv', index=False)

# %%
posts=pd.read_csv('../Data/5241_Model_cleaned.csv') 
base_posts=pd.read_csv('../Data/8322_GoodsVehicleDriver_cleaned.csv')

# %%
plt.figure(figsize=(10,10))
plt.title('Comparing Overlapping Words',fontsize=10)

set_a = set(get_top_post(input=base_posts['job_desc_proc'],ngram_range=(1,1),n=20)['feature_names'])
set_b = set(get_top_post(input=posts['job_desc_proc'],ngram_range=(1,1),n=20)['feature_names'])

venn = venn2([set_a,set_b],set_labels=['Light Goods Driver','Model'],set_colors=('green', 'darkorange'), alpha = 0.7)
venn.get_label_by_id('100').set_text('\n'.join(map(str,set_a-set_b)))
venn.get_label_by_id('110').set_text('\n'.join(map(str,set_a&set_b)))
venn.get_label_by_id('010').set_text('\n'.join(map(str,set_b-set_a)))

# %%
base_top_words_df=get_top_post(base_posts['job_desc_proc'], ngram_range=(1,1), n=1000)
base_top_text = ' '.join(base_top_words_df['feature_names'])

top_words_df=get_top_post(posts['job_desc_proc'], ngram_range=(1,1), n=1000)
top_text = ' '.join(top_words_df['feature_names'])

# %%
df=pd.DataFrame(data={'jobs': ['base_job','adjacent_job'], 'top_text' : [base_top_text,top_text]})
count = CountVectorizer()
count_matrix = count.fit_transform(df['top_text'])
cosine_sim = cosine_similarity(count_matrix)
print(cosine_sim)
# Out:
# [[1.         0.17810176]
#  [0.17810176 1.        ]]
